# %%
import pandas as pd
import geopandas as gpd

# %%
hc_gpd=gpd.read_file('../data/community_centers/Health_Centers.geojson')

# %%
zip_gpd=gpd.read_file('../data/base_geodata/Zipcodes_Poly.geojson')

# %%
base = zip_gpd.plot(color='white', edgecolor='black', figsize=(10,10))
hc_gpd.plot(ax=base, markersize=8)
# Out:
# <AxesSubplot:>

# %%
zip_gpd
# Out:
#     OBJECTID   CODE  COD   Shape__Area  Shape__Length  \
# 0          1  19120   20  9.177970e+07   49921.544063
# 1          2  19121   21  6.959879e+07   39534.887217
# 2          3  19122   22  3.591632e+07   24124.645221
# 3          4  19123   23  3.585175e+07   26421.728982
# 4          5  19124   24  1.448080e+08   63658.770420
# 5          6  19125   25  4.822625e+07   30113.604536
# 6          7  19126   26  3.306658e+07   26114.900637
# 7          8  19127   27  1.624429e+07   29133.850884
# 8          9  19128   28  1.963505e+08   76282.328427
# 9         10  19102    2  4.538805e+06   13170.292163
# 10        11  19103    3  2.068057e+07   21810.024858
# 11        12  19104    4  8.785567e+07   41867.137372
# 12        13  19106    6  2.688774e+07   21331.985714
# 13        14  19107    7  1.486793e+07   17492.276143
# 14        15  19109    9  9.469785e+04    1248.210416
# 15        16  19111   11  1.458023e+08   68750.201529
# ...

# %%
for i,p in zip_gpd.centroid.items():
    print(p.x, p.y)
# Out:
# -75.12011020201732 40.03395770502769
# -75.1796616971498 39.98208048550369
# -75.14612279073549 39.97756401719146
# -75.14646097476653 39.96365985587744
# -75.09368249123109 40.017709834681476
# -75.12455008459517 39.974921804757216
# -75.13716571167647 40.05515537888307
# -75.22632944770872 40.027863918959
# -75.22981003405286 40.04917526223296
# -75.16521190361951 39.95280499165017
# -75.17405343241845 39.95369121814355
# -75.19815914384395 39.95906926429651
# -75.14443025431352 39.950207563808966
# -75.15862110331835 39.951976149492246
# -75.16365661743143 39.94966135360716
# -75.07853557622155 40.06285650646546
# -75.16949231071013 39.88983833977195
# -75.00411863287033 40.06794485063675
# -75.04398514654271 40.09193003778268
# -75.01423329055956 40.116468277057166
# -75.21192076284491 40.072174189528745
# -75.19208487319297 40.05284647100931
# -75.066085580058 40.03685079475801
# -75.17155379768819 40.07245224956495
# -75.25625796332218 39.975611178798644
# ...

# %%
hc_gpd
# Out:
#     OBJECTID                                               NAME  \
# 0          1                  Maria de los Santos Health Center
# 1          2          Maria de los Santos Women's Health Center
# 2          3                Parkview OB/Gyn & Podiatry Services
# 3          4  Fairmount Primary Care Center at Girard Medica...
# 4          5                                                K&A
# 5          6            Esperanza Health Center  (Fifth Street)
# 6          7                                       Hunting Park
# 7          8                                   The Health Annex
# 8          9                 11th Street Family Health Services
# 9         10   Abbotsford Falls  Family Practice and Counseling
# 10        11                                   Fast Family Care
# 11        12                           Annex West Health Center
# 12        13                      Woodland Avenue Health Center
# 13        14                            Southeast Health Center
# ...
